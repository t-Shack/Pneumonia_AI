# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# Use the kagglehub client library to attach Kaggle resources like competitions, datasets, and models to your session
# Learn more about kagglehub: https://github.com/Kaggle/kagglehub/blob/main/README.md

import kagglehub
# kagglehub.dataset_download('<owner>/<dataset-slug>')

# %%
import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# %%
# !git clone https://github.com/t-Shack/Pneumonia_AI.git
# Out:
# Cloning into 'Pneumonia_AI'...
# remote: Enumerating objects: 8952, done.
# remote: Counting objects: 100% (1597/1597), done.
# remote: Compressing objects: 100% (1555/1555), done.
# remote: Total 8952 (delta 47), reused 1573 (delta 38), pack-reused 7355 (from 2)
# Receiving objects: 100% (8952/8952), 2.52 GiB | 50.80 MiB/s, done.
# Resolving deltas: 100% (53/53), done.
# Updating files: 100% (8800/8800), done.

# %%
# %cd ../
# Out:
# /kaggle/working/Pneumonia_AI

# %%
# !pip install -r requirements.txt
# Out:
# Requirement already satisfied: tensorflow>=2.16 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 1)) (2.20.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 2)) (2.0.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 3)) (2.3.3)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 4)) (3.10.0)
# Requirement already satisfied: seaborn in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 5)) (0.13.2)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 6)) (1.6.1)
# Requirement already satisfied: opencv-python-headless in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 7)) (4.13.0.92)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 8)) (11.3.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 9)) (1.16.3)
# Requirement already satisfied: flask>=3.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 10)) (3.1.3)
# Requirement already satisfied: xhtml2pdf in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 11)) (0.2.17)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow>=2.16->-r requirements.txt (line 1)) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow>=2.16->-r requirements.txt (line 1)) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.12/dist-packages (from tensorflow>=2.16->-r requirements.txt (line 1)) (25.12.19)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow>=2.16->-r requirements.txt (line 1)) (0.7.0)
# Requirement already satisfied: google_pasta>=0.1.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow>=2.16->-r requirements.txt (line 1)) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow>=2.16->-r requirements.txt (line 1)) (18.1.1)
# Requirement already satisfied: opt_einsum>=2.3.2 in /usr/local/lib/python3.12/dist-packages (from tensorflow>=2.16->-r requirements.txt (line 1)) (3.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from tensorflow>=2.16->-r requirements.txt (line 1)) (26.1)
# Requirement already satisfied: protobuf>=5.28.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow>=2.16->-r requirements.txt (line 1)) (5.29.5)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow>=2.16->-r requirements.txt (line 1)) (2.32.4)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from tensorflow>=2.16->-r requirements.txt (line 1)) (81.0.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow>=2.16->-r requirements.txt (line 1)) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow>=2.16->-r requirements.txt (line 1)) (3.3.0)
# Requirement already satisfied: typing_extensions>=3.6.6 in /usr/local/lib/python3.12/dist-packages (from tensorflow>=2.16->-r requirements.txt (line 1)) (4.15.0)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow>=2.16->-r requirements.txt (line 1)) (2.1.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.12/dist-packages (from tensorflow>=2.16->-r requirements.txt (line 1)) (1.81.1)
# Requirement already satisfied: tensorboard~=2.20.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow>=2.16->-r requirements.txt (line 1)) (2.20.0)
# Requirement already satisfied: keras>=3.10.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow>=2.16->-r requirements.txt (line 1)) (3.13.2)
# Requirement already satisfied: h5py>=3.11.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow>=2.16->-r requirements.txt (line 1)) (3.16.0)
# Requirement already satisfied: ml_dtypes<1.0.0,>=0.5.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow>=2.16->-r requirements.txt (line 1)) (0.5.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas->-r requirements.txt (line 3)) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->-r requirements.txt (line 3)) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->-r requirements.txt (line 3)) (2026.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->-r requirements.txt (line 4)) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->-r requirements.txt (line 4)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->-r requirements.txt (line 4)) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->-r requirements.txt (line 4)) (1.5.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->-r requirements.txt (line 4)) (3.3.2)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->-r requirements.txt (line 6)) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->-r requirements.txt (line 6)) (3.6.0)
# Requirement already satisfied: blinker>=1.9.0 in /usr/local/lib/python3.12/dist-packages (from flask>=3.0->-r requirements.txt (line 10)) (1.9.0)
# Requirement already satisfied: click>=8.1.3 in /usr/local/lib/python3.12/dist-packages (from flask>=3.0->-r requirements.txt (line 10)) (8.3.3)
# Requirement already satisfied: itsdangerous>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from flask>=3.0->-r requirements.txt (line 10)) (2.2.0)
# Requirement already satisfied: jinja2>=3.1.2 in /usr/local/lib/python3.12/dist-packages (from flask>=3.0->-r requirements.txt (line 10)) (3.1.6)
# Requirement already satisfied: markupsafe>=2.1.1 in /usr/local/lib/python3.12/dist-packages (from flask>=3.0->-r requirements.txt (line 10)) (3.0.3)
# Requirement already satisfied: werkzeug>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from flask>=3.0->-r requirements.txt (line 10)) (3.1.8)
# Requirement already satisfied: arabic-reshaper>=3.0.0 in /usr/local/lib/python3.12/dist-packages (from xhtml2pdf->-r requirements.txt (line 11)) (3.0.1)
# Requirement already satisfied: html5lib>=1.1 in /usr/local/lib/python3.12/dist-packages (from xhtml2pdf->-r requirements.txt (line 11)) (1.1)
# Requirement already satisfied: pyHanko>=0.12.1 in /usr/local/lib/python3.12/dist-packages (from xhtml2pdf->-r requirements.txt (line 11)) (0.36.2)
# Requirement already satisfied: pyhanko-certvalidator>=0.19.5 in /usr/local/lib/python3.12/dist-packages (from xhtml2pdf->-r requirements.txt (line 11)) (0.31.4)
# Requirement already satisfied: pypdf>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from xhtml2pdf->-r requirements.txt (line 11)) (6.14.2)
# Requirement already satisfied: python-bidi>=0.5.0 in /usr/local/lib/python3.12/dist-packages (from xhtml2pdf->-r requirements.txt (line 11)) (0.6.10)
# Requirement already satisfied: reportlab<5,>=4.0.4 in /usr/local/lib/python3.12/dist-packages (from xhtml2pdf->-r requirements.txt (line 11)) (4.5.1)
# Requirement already satisfied: svglib>=1.2.1 in /usr/local/lib/python3.12/dist-packages (from xhtml2pdf->-r requirements.txt (line 11)) (2.2.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from astunparse>=1.6.0->tensorflow>=2.16->-r requirements.txt (line 1)) (0.47.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.12/dist-packages (from html5lib>=1.1->xhtml2pdf->-r requirements.txt (line 11)) (0.5.1)
# Requirement already satisfied: rich in /usr/local/lib/python3.12/dist-packages (from keras>=3.10.0->tensorflow>=2.16->-r requirements.txt (line 1)) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.12/dist-packages (from keras>=3.10.0->tensorflow>=2.16->-r requirements.txt (line 1)) (0.1.0)
# Requirement already satisfied: optree in /usr/local/lib/python3.12/dist-packages (from keras>=3.10.0->tensorflow>=2.16->-r requirements.txt (line 1)) (0.19.0)
# Requirement already satisfied: asn1crypto>=1.5.1 in /usr/local/lib/python3.12/dist-packages (from pyHanko>=0.12.1->xhtml2pdf->-r requirements.txt (line 11)) (1.5.1)
# Requirement already satisfied: tzlocal>=4.3 in /usr/local/lib/python3.12/dist-packages (from pyHanko>=0.12.1->xhtml2pdf->-r requirements.txt (line 11)) (5.3.1)
# Requirement already satisfied: cryptography>=48.0.0 in /usr/local/lib/python3.12/dist-packages (from pyHanko>=0.12.1->xhtml2pdf->-r requirements.txt (line 11)) (50.0.0)
# Requirement already satisfied: lxml>=5.4.0 in /usr/local/lib/python3.12/dist-packages (from pyHanko>=0.12.1->xhtml2pdf->-r requirements.txt (line 11)) (6.1.0)
# Requirement already satisfied: oscrypto>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from pyhanko-certvalidator>=0.19.5->xhtml2pdf->-r requirements.txt (line 11)) (1.3.0)
# Requirement already satisfied: uritools>=3.0.1 in /usr/local/lib/python3.12/dist-packages (from pyhanko-certvalidator>=0.19.5->xhtml2pdf->-r requirements.txt (line 11)) (6.1.3)
# Requirement already satisfied: charset-normalizer in /usr/local/lib/python3.12/dist-packages (from reportlab<5,>=4.0.4->xhtml2pdf->-r requirements.txt (line 11)) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow>=2.16->-r requirements.txt (line 1)) (3.13)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow>=2.16->-r requirements.txt (line 1)) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow>=2.16->-r requirements.txt (line 1)) (2026.4.22)
# Requirement already satisfied: cssselect2>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from svglib>=1.2.1->xhtml2pdf->-r requirements.txt (line 11)) (0.9.0)
# Requirement already satisfied: tinycss2>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from svglib>=1.2.1->xhtml2pdf->-r requirements.txt (line 11)) (1.4.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.12/dist-packages (from tensorboard~=2.20.0->tensorflow>=2.16->-r requirements.txt (line 1)) (3.10.2)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.12/dist-packages (from tensorboard~=2.20.0->tensorflow>=2.16->-r requirements.txt (line 1)) (0.7.2)
# Requirement already satisfied: cffi>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from cryptography>=48.0.0->pyHanko>=0.12.1->xhtml2pdf->-r requirements.txt (line 11)) (2.0.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich->keras>=3.10.0->tensorflow>=2.16->-r requirements.txt (line 1)) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich->keras>=3.10.0->tensorflow>=2.16->-r requirements.txt (line 1)) (2.20.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi>=2.0.0->cryptography>=48.0.0->pyHanko>=0.12.1->xhtml2pdf->-r requirements.txt (line 11)) (3.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.10.0->tensorflow>=2.16->-r requirements.txt (line 1)) (0.1.2)

# %%
# !pip install tensorflow[and-cuda]
# Out:
# Requirement already satisfied: tensorflow[and-cuda] in /usr/local/lib/python3.12/dist-packages (2.20.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow[and-cuda]) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow[and-cuda]) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.12/dist-packages (from tensorflow[and-cuda]) (25.12.19)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow[and-cuda]) (0.7.0)
# Requirement already satisfied: google_pasta>=0.1.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow[and-cuda]) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow[and-cuda]) (18.1.1)
# Requirement already satisfied: opt_einsum>=2.3.2 in /usr/local/lib/python3.12/dist-packages (from tensorflow[and-cuda]) (3.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from tensorflow[and-cuda]) (26.1)
# Requirement already satisfied: protobuf>=5.28.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow[and-cuda]) (5.29.5)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow[and-cuda]) (2.32.4)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from tensorflow[and-cuda]) (81.0.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow[and-cuda]) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow[and-cuda]) (3.3.0)
# Requirement already satisfied: typing_extensions>=3.6.6 in /usr/local/lib/python3.12/dist-packages (from tensorflow[and-cuda]) (4.15.0)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow[and-cuda]) (2.1.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.12/dist-packages (from tensorflow[and-cuda]) (1.81.1)
# Requirement already satisfied: tensorboard~=2.20.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow[and-cuda]) (2.20.0)
# Requirement already satisfied: keras>=3.10.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow[and-cuda]) (3.13.2)
# Requirement already satisfied: numpy>=1.26.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow[and-cuda]) (2.0.2)
# Requirement already satisfied: h5py>=3.11.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow[and-cuda]) (3.16.0)
# Requirement already satisfied: ml_dtypes<1.0.0,>=0.5.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow[and-cuda]) (0.5.4)
# Requirement already satisfied: nvidia-cublas-cu12<13.0,>=12.5.3.2 in /usr/local/lib/python3.12/dist-packages (from tensorflow[and-cuda]) (12.8.4.1)
# Requirement already satisfied: nvidia-cuda-cupti-cu12<13.0,>=12.5.82 in /usr/local/lib/python3.12/dist-packages (from tensorflow[and-cuda]) (12.8.90)
# Requirement already satisfied: nvidia-cuda-nvcc-cu12<13.0,>=12.5.82 in /usr/local/lib/python3.12/dist-packages (from tensorflow[and-cuda]) (12.8.93)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12<13.0,>=12.5.82 in /usr/local/lib/python3.12/dist-packages (from tensorflow[and-cuda]) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12<13.0,>=12.5.82 in /usr/local/lib/python3.12/dist-packages (from tensorflow[and-cuda]) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12<10.0,>=9.3.0.75 in /usr/local/lib/python3.12/dist-packages (from tensorflow[and-cuda]) (9.10.2.21)
# Requirement already satisfied: nvidia-cufft-cu12<12.0,>=11.2.3.61 in /usr/local/lib/python3.12/dist-packages (from tensorflow[and-cuda]) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12<11.0,>=10.3.6.82 in /usr/local/lib/python3.12/dist-packages (from tensorflow[and-cuda]) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12<12.0,>=11.6.3.83 in /usr/local/lib/python3.12/dist-packages (from tensorflow[and-cuda]) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12<13.0,>=12.5.1.3 in /usr/local/lib/python3.12/dist-packages (from tensorflow[and-cuda]) (12.5.8.93)
# Requirement already satisfied: nvidia-nccl-cu12<3.0,>=2.25.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow[and-cuda]) (2.27.5)
# Requirement already satisfied: nvidia-nvjitlink-cu12<13.0,>=12.5.82 in /usr/local/lib/python3.12/dist-packages (from tensorflow[and-cuda]) (12.8.93)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from astunparse>=1.6.0->tensorflow[and-cuda]) (0.47.0)
# Requirement already satisfied: rich in /usr/local/lib/python3.12/dist-packages (from keras>=3.10.0->tensorflow[and-cuda]) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.12/dist-packages (from keras>=3.10.0->tensorflow[and-cuda]) (0.1.0)
# Requirement already satisfied: optree in /usr/local/lib/python3.12/dist-packages (from keras>=3.10.0->tensorflow[and-cuda]) (0.19.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow[and-cuda]) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow[and-cuda]) (3.13)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow[and-cuda]) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow[and-cuda]) (2026.4.22)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.12/dist-packages (from tensorboard~=2.20.0->tensorflow[and-cuda]) (3.10.2)
# Requirement already satisfied: pillow in /usr/local/lib/python3.12/dist-packages (from tensorboard~=2.20.0->tensorflow[and-cuda]) (11.3.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.12/dist-packages (from tensorboard~=2.20.0->tensorflow[and-cuda]) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from tensorboard~=2.20.0->tensorflow[and-cuda]) (3.1.8)
# Requirement already satisfied: markupsafe>=2.1.1 in /usr/local/lib/python3.12/dist-packages (from werkzeug>=1.0.1->tensorboard~=2.20.0->tensorflow[and-cuda]) (3.0.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich->keras>=3.10.0->tensorflow[and-cuda]) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich->keras>=3.10.0->tensorflow[and-cuda]) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.10.0->tensorflow[and-cuda]) (0.1.2)

# %%
# %cd model_training
# Out:
# /kaggle/working/Pneumonia_AI/model_training

# %%
# !pip install cryptography==41.0.7 pyOpenSSL==23.2.0
# Out:
# Collecting cryptography==41.0.7
#   Downloading cryptography-41.0.7-cp37-abi3-manylinux_2_28_x86_64.whl.metadata (5.2 kB)
# Collecting pyOpenSSL==23.2.0
#   Downloading pyOpenSSL-23.2.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.12/dist-packages (from cryptography==41.0.7) (2.0.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi>=1.12->cryptography==41.0.7) (3.0)
# Downloading cryptography-41.0.7-cp37-abi3-manylinux_2_28_x86_64.whl (4.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.4/4.4 MB 92.2 MB/s eta 0:00:00:00:01
# Downloading pyOpenSSL-23.2.0-py3-none-any.whl (59 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.0/59.0 kB 5.0 MB/s eta 0:00:00
# Installing collected packages: cryptography, pyOpenSSL
#   Attempting uninstall: cryptography
#     Found existing installation: cryptography 50.0.0
#     Uninstalling cryptography-50.0.0:
#       Successfully uninstalled cryptography-50.0.0
#   Attempting uninstall: pyOpenSSL
#     Found existing installation: pyOpenSSL 24.2.1
#     Uninstalling pyOpenSSL-24.2.1:
#       Successfully uninstalled pyOpenSSL-24.2.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-adk 1.29.0 requires google-cloud-bigquery-storage>=2.0.0, which is not installed.
# pyhanko 0.36.2 requires cryptography>=48.0.0, but you have cryptography 41.0.7 which is incompatible.
# pyhanko-certvalidator 0.31.4 requires cryptography>=48.0.0, but you have cryptography 41.0.7 which is incompatible.
# rfc3161-client 1.0.6 requires cryptography>=43, but you have cryptography 41.0.7 which is incompatible.
# sigstore 4.3.0 requires cryptography<49,>=42, but you have cryptography 41.0.7 which is incompatible.
# bigquery-magics 0.14.0 requires pyopenssl>=23.3.0, but you have pyopenssl 23.2.0 which is incompatible.
# Successfully installed cryptography-41.0.7 pyOpenSSL-23.2.0

# %%
# !python cross_validate.py --activation sigmoid --folds 5
# !python cross_validate.py --activation softmax --folds 5
# Out:
# Total training-pool images: 5216 ({'PNEUMONIA': 3875, 'NORMAL': 1341})
#
# ======================================================================
# Fold 1/5 — sigmoid
# ======================================================================
# Found 4172 validated image filenames belonging to 2 classes.
# Found 1044 validated image filenames belonging to 2 classes.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1786836283.690759     393 gpu_device.cc:2020] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13756 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# I0000 00:00:1786836283.694039     393 gpu_device.cc:2020] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 13756 MB memory:  -> device: 1, name: Tesla T4, pci bus id: 0000:00:05.0, compute capability: 7.5
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/densenet/densenet121_weights_tf_dim_ordering_tf_kernels_notop.h5
# 29084464/29084464 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Class-balanced focal alpha ({'NORMAL': 0.7430488974113135, 'PNEUMONIA': 0.2569511025886865})
# Epoch 1/5
# I0000 00:00:1786836317.162448     426 device_compiler.h:196] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 149s 931ms/step - accuracy: 0.6637 - loss: 0.0685 - val_accuracy: 0.7423 - val_loss: 0.0630
# Epoch 2/5
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 85s 648ms/step - accuracy: 0.8310 - loss: 0.0401 - val_accuracy: 0.8487 - val_loss: 0.0245
# Epoch 3/5
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 87s 665ms/step - accuracy: 0.9005 - loss: 0.0258 - val_accuracy: 0.9397 - val_loss: 0.0171
# Epoch 4/5
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 85s 650ms/step - accuracy: 0.9125 - loss: 0.0216 - val_accuracy: 0.9330 - val_loss: 0.0149
# Epoch 5/5
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 85s 650ms/step - accuracy: 0.9221 - loss: 0.0202 - val_accuracy: 0.9282 - val_loss: 0.0145
# Unfroze 107 of 427 backbone layers (76 actually trainable after re-freezing 31 BatchNorm layers).
# Epoch 1/30
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 152s 924ms/step - accuracy: 0.9391 - loss: 0.0169 - val_accuracy: 0.9559 - val_loss: 0.0109
# Epoch 2/30
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 85s 644ms/step - accuracy: 0.9365 - loss: 0.0158 - val_accuracy: 0.9339 - val_loss: 0.0124
# Epoch 3/30
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 85s 650ms/step - accuracy: 0.9446 - loss: 0.0144 - val_accuracy: 0.9550 - val_loss: 0.0101
# Epoch 4/30
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 85s 650ms/step - accuracy: 0.9533 - loss: 0.0125 - val_accuracy: 0.9444 - val_loss: 0.0109
# Epoch 5/30
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 85s 648ms/step - accuracy: 0.9573 - loss: 0.0110 - val_accuracy: 0.9483 - val_loss: 0.0100
# Epoch 6/30
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 85s 648ms/step - accuracy: 0.9571 - loss: 0.0110 - val_accuracy: 0.9454 - val_loss: 0.0111
# Epoch 7/30
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 86s 655ms/step - accuracy: 0.9624 - loss: 0.0098 - val_accuracy: 0.9569 - val_loss: 0.0095
# Epoch 8/30
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 85s 651ms/step - accuracy: 0.9672 - loss: 0.0089 - val_accuracy: 0.9416 - val_loss: 0.0121
# Epoch 9/30
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 85s 648ms/step - accuracy: 0.9672 - loss: 0.0094 - val_accuracy: 0.9330 - val_loss: 0.0128
# Epoch 10/30
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 85s 651ms/step - accuracy: 0.9681 - loss: 0.0074 - val_accuracy: 0.9569 - val_loss: 0.0104
# Epoch 11/30
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 86s 654ms/step - accuracy: 0.9696 - loss: 0.0081 - val_accuracy: 0.9262 - val_loss: 0.0157
# Epoch 12/30
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 86s 654ms/step - accuracy: 0.9676 - loss: 0.0084 - val_accuracy: 0.9435 - val_loss: 0.0111
# Epoch 13/30
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 86s 657ms/step - accuracy: 0.9667 - loss: 0.0088 - val_accuracy: 0.9473 - val_loss: 0.0102
# Epoch 13: early stopping
# Restoring model weights from the end of the best epoch: 7.
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:3001: UserWarning: The y_pred values do not sum to one. Make sure to pass probabilities.
#   warnings.warn(
# Fold 1 result: {'fold': 1, 'val_accuracy': 0.9568965517241379, 'val_macro_f1': 0.9462293595937329, 'val_log_loss': 0.22959682320349897}
#
# ======================================================================
# Fold 2/5 — sigmoid
# ======================================================================
# Found 4173 validated image filenames belonging to 2 classes.
# Found 1043 validated image filenames belonging to 2 classes.
# Class-balanced focal alpha ({'NORMAL': 0.7428708363287803, 'PNEUMONIA': 0.2571291636712198})
# Epoch 1/5
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 146s 941ms/step - accuracy: 0.7000 - loss: 0.0692 - val_accuracy: 0.8859 - val_loss: 0.0331
# Epoch 2/5
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 86s 659ms/step - accuracy: 0.8423 - loss: 0.0353 - val_accuracy: 0.9128 - val_loss: 0.0212
# Epoch 3/5
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 86s 655ms/step - accuracy: 0.8898 - loss: 0.0273 - val_accuracy: 0.8984 - val_loss: 0.0199
# Epoch 4/5
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 86s 654ms/step - accuracy: 0.9135 - loss: 0.0222 - val_accuracy: 0.9262 - val_loss: 0.0174
# Epoch 5/5
#  40/131 ━━━━━━━━━━━━━━━━━━━━ 54s 595ms/step - accuracy: 0.9223 - loss: 0.0197

# %%
# !zip -r outputs.zip outputs
